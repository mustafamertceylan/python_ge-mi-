# %%
list1=["apple","banana","milk","pear",14,866,14.45]
print(type(list1))
print(list1)
print(len(list1))
# Out:
# <class 'list'>
# ['apple', 'banana', 'milk', 'pear', 14, 866, 14.45]
# 7

# %%
list_deneme=[1,2,4,"deneme",[4,6,3],["string","integer","float"]]
print(len(list_deneme))
print(list_deneme[4][0])
# Out:
# 6
# 4

# %%
print(list1)
print(list1[0])
print(list1[-1])
print(list1[8])
# Out:
# ['apple', 'banana', 'milk', 'pear', 14, 866, 14.45]
# apple
# 14.45
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[7], line 4
#       2 print(list1[0])
#       3 print(list1[-1])
# ----> 4 print(list1[8])
#
# IndexError: list index out of range

# %%
print(list1)
print(list1[2::2])
print(list1[1:6])
print(list1[::-1])
# Out:
# ['apple', 'banana', 'milk', 'pear', 14, 866, 14.45]
# ['milk', 14, 14.45]
# ['banana', 'milk', 'pear', 14, 866]
# [14.45, 866, 14, 'pear', 'milk', 'banana', 'apple']

# %%
print(list1)
list1.append("Black")
list1.append("white")
list1.insert(4,"red")

print(list1)
sil="Black" 
list1=[x for x in list1 if x != sil ]
print(list1)

print(list1)
sil="white" 
list1=[x for x in list1 if x != sil ]
print(list1)

print(list1)
sil="red" 
list1=[x for x in list1 if x != sil ]
print(list1)
# Out:
# ['apple', 'banana', 'milk', 'pear', 'red', 'red', 'red', 'red', 'red', 14, 866, 14.45, 'white', 'white', 'white', 'white', 'white', 'white', 'white']
# ['apple', 'banana', 'milk', 'pear', 'red', 'red', 'red', 'red', 'red', 'red', 14, 866, 14.45, 'white', 'white', 'white', 'white', 'white', 'white', 'white', 'Black', 'white']
# ['apple', 'banana', 'milk', 'pear', 'red', 'red', 'red', 'red', 'red', 'red', 14, 866, 14.45, 'white', 'white', 'white', 'white', 'white', 'white', 'white', 'white']
# ['apple', 'banana', 'milk', 'pear', 'red', 'red', 'red', 'red', 'red', 'red', 14, 866, 14.45, 'white', 'white', 'white', 'white', 'white', 'white', 'white', 'white']
# ['apple', 'banana', 'milk', 'pear', 'red', 'red', 'red', 'red', 'red', 'red', 14, 866, 14.45]
# ['apple', 'banana', 'milk', 'pear', 'red', 'red', 'red', 'red', 'red', 'red', 14, 866, 14.45]
# ['apple', 'banana', 'milk', 'pear', 14, 866, 14.45]

# %%
print(list1)
list2=["black","white","red"]
list1.append(list2)
print(list1)
list1.remove(list2) 
print(list1)

list1.extend(list2)
print(list1)
# Out:
# ['apple', 'banana', 'milk', 'pear', 14, 866, 14.45, 'black', 'white', 'red', 'black', 'white', 'red']
# ['apple', 'banana', 'milk', 'pear', 14, 866, 14.45, 'black', 'white', 'red', 'black', 'white', 'red', ['black', 'white', 'red']]
# ['apple', 'banana', 'milk', 'pear', 14, 866, 14.45, 'black', 'white', 'red', 'black', 'white', 'red']
# ['apple', 'banana', 'milk', 'pear', 14, 866, 14.45, 'black', 'white', 'red', 'black', 'white', 'red', 'black', 'white', 'red']

# %%
print(list1)

print(list1.pop())
print(list1.pop())
print(list1.pop())



print(list1)
# Out:
# [14.45, 866, 14, 'pear', 'milk', 'banana', 'apple']
# apple
# banana
# milk
# [14.45, 866, 14, 'pear']

# %%
print(list1)
list1.reverse()
print(list1)
list1.sort()
print(list1)
# Out:
# [14.45, 866, 14, 'pear', 'milk', 'banana', 'apple']
# ['apple', 'banana', 'milk', 'pear', 14, 866, 14.45]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 4
#       2 list1.reverse()
#       3 print(list1)
# ----> 4 list1.sort()
#       5 print(list1)
#
# TypeError: '<' not supported between instances of 'int' and 'str'
